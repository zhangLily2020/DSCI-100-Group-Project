# %% [markdown]
# # DSCI100: Group31 Project Proposal
# ### Members
# - Divya Gupta
# - Arshdeep Jassi
# - Cassiel Jung
# - Lily Zhang
#
# ## 1.0 Introduction
# When watching tennis games, players who have high rank seem to have a similar physique. Our team got curious if there is a certain favorable body type for a tennis player. Thus, throughout this project, we are going to answer the question **“What is the relationship between the physique of players and their probability of winning?”**. To answer the question, the dataset *‘Game results for Top 500 Players from 2017-2019’* will be used which contains the data of each tennis game played by Top 500 Players. Each row corresponds to each game and it includes information of players such as their height, age, and hand.
#
# ## 2.0 Preliminary exploratory data analysis
# ### 2.1 Read data from the web
# Libraries to use:
# 1. tidyverse: to use read_csv/ggplot and many other basic data analysis functions
# 2. repre: to represent string/binary variables
# 3. tidymodels: to use regression model later

# %%
library(tidyverse)
library(repr)
library(tidymodels)

# %% [markdown]
# Loading dataset from the google drive using read_csv() function

# %%
tennis_data <- read_csv("https://drive.google.com/uc?export=download&id=1fOQ8sy_qMkQiQEAO6uFdRX4tLI8EpSTn")
tennis_data
# Out:
# Warning message:
# “Missing column names filled in: 'X1' [1]”
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   tourney_id = col_character(),
#   tourney_name = col_character(),
#   surface = col_character(),
#   tourney_level = col_character(),
#   winner_seed = col_character(),
#   winner_entry = col_character(),
#   winner_name = col_character(),
#   winner_hand = col_character(),
#   winner_ioc = col_character(),
#   loser_seed = col_character(),
#   loser_entry = col_character(),
#   loser_name = col_character(),
#   loser_hand = col_character(),
#   loser_ioc = col_character(),
#   score = col_character(),
#   round = col_character()
# )
#
# See spec(...) for full column specifications.
#      X1   tourney_id                     tourney_name               surface
# 1    0    2019-M020                      Brisbane                   Hard
# 2    1    2019-M020                      Brisbane                   Hard
# 3    2    2019-M020                      Brisbane                   Hard
# ⋮    ⋮    ⋮                              ⋮                          ⋮
# 6864 2883 2017-M-DC-2017-WG-M-BEL-FRA-01 Davis Cup WG F: BEL vs FRA Hard
# 6865 2884 2017-M-DC-2017-WG-M-BEL-FRA-01 Davis Cup WG F: BEL vs FRA Hard
# 6866 2885 2017-M-DC-2017-WG-M-BEL-FRA-01 Davis Cup WG F: BEL vs FRA Hard
#      draw_size tourney_level tourney_date match_num winner_id winner_seed ⋯
# 1    32        A             20181231     300       105453    2           ⋯
# 2    32        A             20181231     299       106421    4           ⋯
# 3    32        A             20181231     298       105453    2           ⋯
# ⋮    ⋮         ⋮             ⋮            ⋮         ⋮         ⋮           ⋱
# 6864 4         D             20171124     2         104542    NA          ⋯
# 6865 4         D             20171124     4         105676    NA          ⋯
# 6866 4         D             20171124     5         106298    NA          ⋯
#      l_1stIn l_1stWon l_2ndWon l_SvGms l_bpSaved l_bpFaced winner_rank
# 1    54      34       20       14      10        15         9
# 2    52      36        7       10      10        13        16
# 3    27      15        6        8       1         5         9
# ⋮    ⋮       ⋮        ⋮        ⋮       ⋮         ⋮         ⋮
# 6864 54      30       12       12      5         11        15
# 6865 54      44       13       14      7         10         7
# 6866 53      29       11       11      4         11        18
#      winner_rank_points loser_rank loser_rank_points
# 1    3590                16        1977
# 2    1977               239         200
# 3    3590                40        1050
# ⋮    ⋮                  ⋮          ⋮
# 6864 2320               76          667
# 6865 3775               15         2320
# 6866 2235               76          667

# %% [markdown]
# ### 2.2 Clean and Wrangling the dataset
# Data was already in the clear format and wrangling was not needed.
#
# ### 2.3 Splitting dataset
# Split dataset into two: 75% of train set and 25% of test set

# %%
set.seed(42) 
tennis_split <- initial_split(tennis_data, prop = 0.75)  
tennis_train <- training(tennis_split)
tennis_train
tennis_test <- testing(tennis_split)
tennis_test
# Out:
#      X1   tourney_id                     tourney_name               surface
# 1    0    2019-M020                      Brisbane                   Hard
# 2    3    2019-M020                      Brisbane                   Hard
# 3    4    2019-M020                      Brisbane                   Hard
# ⋮    ⋮    ⋮                              ⋮                          ⋮
# 5148 2882 2017-M-DC-2017-WG-M-BEL-FRA-01 Davis Cup WG F: BEL vs FRA Hard
# 5149 2883 2017-M-DC-2017-WG-M-BEL-FRA-01 Davis Cup WG F: BEL vs FRA Hard
# 5150 2884 2017-M-DC-2017-WG-M-BEL-FRA-01 Davis Cup WG F: BEL vs FRA Hard
#      draw_size tourney_level tourney_date match_num winner_id winner_seed ⋯
# 1    32        A             20181231     300       105453    2           ⋯
# 2    32        A             20181231     297       104542    NA          ⋯
# 3    32        A             20181231     296       106421    4           ⋯
# ⋮    ⋮         ⋮             ⋮            ⋮         ⋮         ⋮           ⋱
# 5148 4         D             20171124     1         105676    NA          ⋯
# 5149 4         D             20171124     2         104542    NA          ⋯
# 5150 4         D             20171124     4         105676    NA          ⋯
#      l_1stIn l_1stWon l_2ndWon l_SvGms l_bpSaved l_bpFaced winner_rank
# 1    54      34       20       14      10        15          9
# 2    60      38        9       11       4         6        239
# 3    56      46       19       15       2         4         16
# ⋮    ⋮       ⋮        ⋮        ⋮       ⋮         ⋮         ⋮
# 5148 53      33       21       14      6         11         7
# 5149 54      30       12       12      5         11        15
# 5150 54      44       13       14      7         10         7
#      winner_rank_points loser_rank loser_rank_points
# 1    3590               16         1977
# 2     200               31         1298
# 3    1977               18         1855
# ⋮    ⋮                  ⋮          ⋮
# 5148 3775               18         2235
# 5149 2320               76          667
# 5150 3775               15         2320
#      X1   tourney_id                     tourney_name               surface
# 1    1    2019-M020                      Brisbane                   Hard
# 2    2    2019-M020                      Brisbane                   Hard
# 3    7    2019-M020                      Brisbane                   Hard
# ⋮    ⋮    ⋮                              ⋮                          ⋮
# 1714 2867 2017-0605                      Tour Finals                Hard
# 1715 2881 2017-0605                      Tour Finals                Hard
# 1716 2885 2017-M-DC-2017-WG-M-BEL-FRA-01 Davis Cup WG F: BEL vs FRA Hard
#      draw_size tourney_level tourney_date match_num winner_id winner_seed ⋯
# 1    32        A             20181231     299       106421    4           ⋯
# 2    32        A             20181231     298       105453    2           ⋯
# 3    32        A             20181231     293       104542    NA          ⋯
# ⋮    ⋮         ⋮             ⋮            ⋮         ⋮         ⋮           ⋱
# 1714 8         F             20171113     286       105676    7.0         ⋯
# 1715 8         F             20171113     300       105777    6.0         ⋯
# 1716 4         D             20171124       5       106298    NA          ⋯
#      l_1stIn l_1stWon l_2ndWon l_SvGms l_bpSaved l_bpFaced winner_rank
# 1    52      36        7       10      10        13         16
# 2    27      15        6        8       1         5          9
# 3    51      34       11       11       6        11        239
# ⋮    ⋮       ⋮        ⋮        ⋮       ⋮         ⋮         ⋮
# 1714 NA      NA       NA       NA      NA        NA         8
# 1715 54      42       22       15      11        15         6
# 1716 53      29       11       11       4        11        18
#      winner_rank_points loser_rank loser_rank_points
# 1    1977               239         200
# 2    3590                40        1050
# 3     200                77         691
# ⋮    ⋮                  ⋮          ⋮
# 1714 2975                1         10645
# 1715 3650                8          2975
# 1716 2235               76           667

# %% [markdown]
# ### 2.4 Summarize data
# #### 2.4.1 Summarize quantitative variables
# One of the metrics that can be explored is the average values of the quantitative variables we are considering in the analysis such as height and age. The table below shows the average height (in cm) and age (years) of both the winners and the losers. As seen below, the average height and age of both winners and losers is similar.

# %%
tennis_avg_summarization <- tennis_train %>% 
    select(winner_ht, winner_age, loser_ht, loser_age) %>% 
    summarize(avg_win_height = mean(winner_ht, na.rm = TRUE),
              avg_win_age = mean(winner_age, na.rm = TRUE), 
              avg_loser_height = mean(loser_ht, na.rm = TRUE), 
              avg_loser_age = mean(loser_age, na.rm = TRUE))

tennis_avg_summarization
# Out:
#   avg_win_height avg_win_age avg_loser_height avg_loser_age
# 1 186.4946       27.76596    186.322          27.5366

# %% [markdown]
# #### 2.4.2 Summarize categorical variable
# There is one more variable we are considering for the analysis which is handedness of the players. Since it is a categorical variable, to explore the number of games won with each dominant hand, we can just count up the number of winners for each dominant hand. This can be seen in the following table.

# %%
tennis_num_winners_hand <- tennis_train %>% 
    select(winner_hand) %>% 
    group_by(winner_hand) %>% 
    summarize(number_winners = n())

tennis_num_winners_hand
# Out:
# `summarise()` ungrouping output (override with `.groups` argument)
#   winner_hand number_winners
# 1 L            760
# 2 R           4341
# 3 U             49

# %% [markdown]
# ### 2.5 Visualize summarized data
# #### 2.5.1 Winning games vs Winner's handedness
# By using the tennis_num_winners_hand assigned previously, a visual representation can be created that compares the number of games won with the different handedness of players using bar plots. Colour-blind friendly colours were also added to help better visualize the plot. This was done using the ggplot and geom_bar functions.

# %%
options(repr.plot.height = 7, repr.plot.width = 12)
library(RColorBrewer)

winning_hand_visual <- ggplot(tennis_num_winners_hand, aes(x = winner_hand, y = number_winners, fill = winner_hand)) +
                            geom_bar(stat = "identity") +
                            labs(x = "Main hand", y = "Number of games won", fill = "Winner's main hand used for the game") +
                            ggtitle("Winning games vs. Winner's main hand") +
                            theme(text = element_text(size = 20)) +
                            scale_fill_brewer(palette = 'Paired')

winning_hand_visual
# Out:
# plot without title

# %% [markdown]
# #### 2.5.2 Winning games vs Winner's height
# By using the testing data set, a histogram can be produced that visualizes the distribution of winning games for winner’s heights. This was done using the ggplot and geom_histogram functions.

# %%
options(repr.plot.height = 7, repr.plot.width = 8)
winning_height_visual <- tennis_train %>%
                    ggplot(aes(x = winner_ht)) +
                    geom_histogram(bins = 20) +
                    labs(x = "Winner's height (cm)", y = "Number of games won") +
                    ggtitle("Winning games vs. Winner's height") +
                    theme(text = element_text(size = 20))
                    

winning_height_visual
# Out:
# Warning message:
# “Removed 1626 rows containing non-finite values (stat_bin).”
# plot without title

# %% [markdown]
# ### 2.4.3 Winning games vs Winner's age
# Similar to the previous graph and using the same data, a histogram is also used to visualize the distribution of the winning games for the winner’s age. This was done using the ggplot and geom_histogram functions.

# %%
options(repr.plot.height = 7, repr.plot.width = 8)
winning_age_visual <- tennis_train %>%
                    ggplot(aes(x = winner_age)) +
                    geom_histogram(bins = 30) +
                    labs(x = "Winner's age (years)", y = "Number of games won") +
                    ggtitle("Winning games vs. Winner's age") +
                    theme(text = element_text(size = 20))
                    

winning_age_visual
# Out:
# plot without title

# %% [markdown]
# ## 3.0 Method
# Any columns that include information about the tourney or the score won’t be used.
#
# We first need to obtain the winning probability of each player between 2017 to 2019 to map it to their physique. Two columns will be used to compute: winner_id and loser_id. We will count the number of appearances as a winner_id divided by the total number of games the player played to calculate the winning probability.
#
# After calculating the winning probability, we should have a tibble with two columns player_id and winning_prob. We are going to add the physique of each player as new columns. We are going to scale and center variables before we put them into the regression model.
#
# The winning probability will be the dependent variable and player information will be the independent variable. For the visualization, to make graphs easy to read and see the relationship, each independent variable vs winning probability will be plotted separately. For height and age, we will plot a scatter graph and for the main hand of the player, a bar graph will be used to plot.
#
# ## 4.0 Expected outcomes and significance
# We are expecting results to be:
# 1. Height has a positive relationship with winning probability
# 2. Age has a negative relationship with winning probability
# 3. Right-handed players will have a higher winning probability
#
# The relationship we found would help people to predict the winner of the game. It could also be used to determine if a player has a favorable physique to play tennis or not.
#
# Since we did not consider factors other than the physical type of players, for the future we may use the surface type or skills that each player has to determine in which tennis stadium players show the best performance.
